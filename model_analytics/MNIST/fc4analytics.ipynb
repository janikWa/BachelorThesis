# %% [markdown]
# <h1> Training Results Analysis | MNIST </h1>

# %% [markdown]
# <h2> Gaussian Init - SGD</h2>

# %%
import sys
import os 

project_root = "/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code"

sys.path.append(project_root)

# %%
import h5py
import numpy as np
import polars as pl
import numpy as np
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri, numpy2ri, default_converter
import rpy2.robjects as ro
from data.h5pydb import load_h5_as_polars_v2
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# path_none_sgd= r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/fc3_mnist_None_sgd_mnist_log.h5"
# path_lasso_sgd = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/fc3_mnist_lasso_sgd_mnist_log.h5"
# path_hill_sgd = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/fc3_mnist_hill_sgd_mnist_log.h5"
# path_parabolic_hill_sgd = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/sgd/fc3_mnist_parabolic_hill_sgd_mnist_log.h5"
# path_parabolic_hill_full_sgd = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/fc3_mnist_parabolic_hill_sgd_mnist_log_all_layers.h5"
# path_xiao = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/fc3_mnist_xiao_sgd_mnist_log.h5"
# path_decay = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/fc3_mnist_decay_sgd_mnist_log.h5"

path_none_sgd= r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/sgd/fc3_mnist_None_sgd_mnist_log.h5"
path_lasso_sgd = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/sgd/fc3_mnist_lasso_sgd_mnist_log.h5"
path_hill_sgd = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/sgd/fc3_mnist_hill_sgd_mnist_log.h5"
path_parabolic_hill_sgd = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/sgd/fc3_mnist_parabolic_hill_sgd_mnist_log.h5"
path_parabolic_hill_full_sgd = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/fc3_mnist_parabolic_hill_sgd_mnist_log_all_layers.h5"
path_xiao = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/sgd/fc3_mnist_xiao_sgd_mnist_log.h5"
path_decay = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/sgd/fc3_mnist_decay_sgd_mnist_log.h5"

# %%
df_none_sgd  = load_h5_as_polars_v2(path_none_sgd)

# %%
df_lasso_sgd = load_h5_as_polars_v2(path_lasso_sgd)

# %%
df_hill_sgd = load_h5_as_polars_v2(path_hill_sgd)

# %%
df_parabolic_hill = load_h5_as_polars_v2(path_parabolic_hill_sgd)

# %%
df_parabolic_hill_full = load_h5_as_polars_v2(path_parabolic_hill_full_sgd)

# %%
df_xiao = load_h5_as_polars_v2(path_xiao)

# %%
df_decay = load_h5_as_polars_v2(path_decay)

# %%
fig, ax = plt.subplots(figsize=(15, 10))

sns.lineplot(x="epoch", y="val_accuracy", data=df_none_sgd, label="None", ax=ax)
sns.lineplot(x="epoch", y="val_accuracy", data=df_lasso_sgd, label="Lasso", ax=ax)
sns.lineplot(x="epoch", y="val_accuracy", data=df_hill_sgd, label="Hill", ax=ax, errorbar="sd")
sns.lineplot(x="epoch", y="val_accuracy", data=df_parabolic_hill, label="Parabolic Hill", ax=ax)
sns.lineplot(x="epoch", y="val_accuracy", data=df_parabolic_hill_full, label="Parabolic Hill Full", ax=ax)
sns.lineplot(x="epoch", y="val_accuracy", data=df_xiao, label="Xiao", ax=ax)
sns.lineplot(x="epoch", y="val_accuracy", data=df_decay, label="Decay", ax=ax)
    
ax.set_xlabel("Epoch")
ax.set_ylabel("Validation Accuracy")
ax.legend(title="Regularizer")

# %%
fig, ax = plt.subplots(figsize=(15, 10))

sns.lineplot(x="epoch", y="accuracy", data=df_none_sgd, label="None", ax=ax)
sns.lineplot(x="epoch", y="accuracy", data=df_lasso_sgd, label="Lasso", ax=ax)
sns.lineplot(x="epoch", y="accuracy", data=df_hill_sgd, label="Hill", ax=ax, errorbar="sd")
sns.lineplot(x="epoch", y="accuracy", data=df_parabolic_hill, label="Parabolic Hill", ax=ax)
sns.lineplot(x="epoch", y="accuracy", data=df_parabolic_hill_full, label="Parabolic Hill Full", ax=ax)
sns.lineplot(x="epoch", y="accuracy", data=df_xiao, label="Xiao", ax=ax)
sns.lineplot(x="epoch", y="accuracy", data=df_decay, label="Decay", ax=ax)
    
ax.set_xlabel("Epoch")
ax.set_ylabel("Validation Accuracy")
ax.legend(title="Regularizer")

# %%
df_concat = pl.concat([df_none_sgd, df_lasso_sgd, df_parabolic_hill, df_parabolic_hill_full, df_hill_sgd, df_xiao, df_decay])

# %%
epochs = 10

fig, axes = plt.subplots(figsize=(30, 30), ncols=2, nrows=int(epochs/2))

axes = axes.flatten()
handles_labels = []

for epoch, ax in zip(range(epochs), axes):

    df_epoch = df_concat.filter(
        (pl.col("epoch") == epoch) &
        (pl.col("layer").str.slice(-1).cast(int) <4)
    )

    sns.lineplot(
        data=df_epoch,
        x="layer",
        y="alpha",
        hue="model",
        ax=ax
    )

    ax.set_title(f"Epoch {epoch}")
    try:
        ax.get_legend().remove()
    except: 
        continue
    if not handles_labels:
        handles, labels = ax.get_legend_handles_labels()
        handles_labels = (handles, labels)



fig.legend(
    handles_labels[0],
    handles_labels[1],
    title="Model",
    loc="lower left",

)
fig.suptitle("Alpha Across Layers per Epoch", fontsize=12)


plt.tight_layout()
plt.show()

# %%
layers = 4

fig, axes = plt.subplots(figsize=(15, 10), ncols=2, nrows=int(layers/2))

axes = axes.flatten()
handles_labels = []

for layer, ax in zip(range(layers), axes):

    df_epoch = df_concat.filter(
        (pl.col("layer").str.slice(-1).cast(int) == layer))

    sns.lineplot(
        data=df_epoch,
        x="epoch",
        y="alpha",
        hue="model",
        ax=ax
    )

    ax.set_title(f"Layer {layer+1}")
    if not handles_labels:
        handles, labels = ax.get_legend_handles_labels()
        handles_labels = (handles, labels)
    ax.get_legend().remove()


fig.legend(
    handles_labels[0],
    handles_labels[1],
    title="Model",
    loc="lower left",

)
fig.suptitle("Alpha Across Epochs per Layer", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> Gaussian Init - ADAM </h2>

# %%
path_none_adam= r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/adam/fc3_mnist_None_adam_mnist_log.h5"
path_lasso_adam = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/adam/fc3_mnist_lasso_adam_mnist_log.h5"
path_hill_adam = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/adam/fc3_mnist_hill_adam_mnist_log.h5"
path_parabolic_hill_adam = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/adam/fc3_mnist_parabolic_hill_adam_mnist_log.h5"
#path_parabolic_hill_full_adam = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/fc3_mnist_parabolic_hill_adam_mnist_log_all_layers.h5"
path_xiao_adam = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/adam/fc3_mnist_xiao_adam_mnist_log.h5"
path_decay_adam = r"/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/Bachelorarbeit/Code/data/training_results/MNIST/FC3/adam/fc3_mnist_decay_adam_mnist_log.h5"

# %%
df_none_adam  = load_h5_as_polars_v2(path_none_adam)

# %%
df_lasso_adam = load_h5_as_polars_v2(path_lasso_adam)

# %%
df_hill_adam = load_h5_as_polars_v2(path_hill_adam)

# %%
df_parabolic_adam= load_h5_as_polars_v2(path_parabolic_hill_adam)

# %%
#df_parabolic_hill_full = load_h5_as_polars_v2(path_parabolic_hill_full_adam)

# %%
df_xiao_adam = load_h5_as_polars_v2(path_xiao_adam)

# %%
df_decay_adam = load_h5_as_polars_v2(path_decay_adam)

# %%
fig, ax = plt.subplots(figsize=(15, 10))

sns.lineplot(x="epoch", y="accuracy", data=df_none_adam, label="None", ax=ax)
sns.lineplot(x="epoch", y="accuracy", data=df_lasso_adam, label="Lasso", ax=ax)
sns.lineplot(x="epoch", y="accuracy", data=df_hill_adam, label="Hill", ax=ax, errorbar="sd")
sns.lineplot(x="epoch", y="accuracy", data=df_parabolic_adam, label="Parabolic Hill", ax=ax)
# sns.lineplot(x="epoch", y="val_accuracy", data=df_xiao_adam, label="Xiao", ax=ax)
# sns.lineplot(x="epoch", y="val_accuracy", data=df_decay_adam, label="Decay", ax=ax)
    
ax.set_xlabel("Epoch")
ax.set_ylabel("Validation Accuracy")
ax.legend(title="Regularizer")
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
